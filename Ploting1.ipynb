# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from numpy.random import default_rng

# %matplotlib inline

# %%
fig, ax = plt.subplots(figsize=(12,8)) #una figura y un eje

# %%
fig, axs = plt.subplots(2,3) #con más de un eje, usar axs

# %%
fig, ax = plt.subplots(figsize=(8,2))
ax.text(0.25, 0.4, "Hola mundo", fontsize=35)
# Out:
# Text(0.25, 0.4, 'Hola mundo')

# %%
fig, axs = plt.subplots(2,3)
print(axs.shape)
print(axs)
# Out:
# (2, 3)
# [[<AxesSubplot:> <AxesSubplot:> <AxesSubplot:>]
#  [<AxesSubplot:> <AxesSubplot:> <AxesSubplot:>]]

# %%
fig, axs = plt.subplots(2,3, figsize=(8,4))
for i, ax in enumerate (axs.flatten()):
    texto=f"Grafico #{i}"
    ax.text(0.1,0.4, texto, fontsize=15)
    
fig.tight_layout()

# %%
fig, axs = plt.subplots()
ax.set_title("Primer gráfico con titulo");

# %%
fig, axs = plt.subplots(2,3)
for i, ax in enumerate (axs.flatten()):
    ax.set_title(f"Grafico #{i}")
fig.tight_layout()

# %%
fig, axs = plt.subplots(2,3)
for i,row in enumerate (axs):
    for j,ax in enumerate(row):
        ax.set_title(f"Grafico index #{j}")
fig.tight_layout()

# %%
fig, axs = plt.subplots(2,3)
axs[0,0].set_title("Gráfico inicial")
axs[0,1].set_title("Gráfico segundo")
fig.tight_layout()

# %%
fig, ax = plt.subplots()
ax.set_title("Gráfico inicial")
ax.set_ylabel("Etiqueta y")
ax.set_xlabel("Etiqueta x")
fig.tight_layout()

# %%
rng = default_rng(17)
size=5000
x=rng.normal(size=size)
y=rng.normal(size=size)

fig, ax = plt.subplots()
ax.scatter(x,y, alpha=0.3)
plt.show()

# %%
rng = default_rng(18)
size=100
x=rng.uniform(size=size)
y=1.0*x+rng.normal(scale=0.2, size=size) #y=mx+b

fig, ax = plt.subplots()
ax.scatter(x,y)
plt.show()

# %%
rng = default_rng(19)
size=100

x_azul=rng.uniform(size=size)
y_azul=1.0*x_azul+rng.normal(scale=0.2, size=size)

x_rojo=rng.uniform(size=size)
y_rojo=1.0-1.0*x_rojo+rng.normal(scale=0.2, size=size)

fig, ax = plt.subplots()
ax.scatter(x_azul,y_azul, color="blue")
ax.scatter(x_rojo,y_rojo, color="red")
plt.show()
